# %% [markdown]
# ## 单元格

# %%
#这是一个代码单元格
print("hello Jupyter")
# Out:
# hello Jupyter

# %%
#标题示例

# %% [markdown]
# # 一级标题
# ## 二级标题
# ### 三级标题
# #### 四级标题
# ##### 五级标题
# ###### 六级标题

# %% [markdown]
# ## 魔法命令

# %%
# %time print ('hello world')
# Out:
# hello world
# CPU times: user 85 µs, sys: 9 µs, total: 94 µs
# Wall time: 73.2 µs

# %%
# %time
# Out:
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 9.78 µs

# %%
# %%time
print('hello world')
print(1+1)
# Out:
# hello world
# 2
# CPU times: user 223 µs, sys: 0 ns, total: 223 µs
# Wall time: 205 µs

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %colors?

# %%
# %%time?

# %%
# %time print('hello world')
# Out:
# hello world
# CPU times: user 35 µs, sys: 3 µs, total: 38 µs
# Wall time: 41 µs

# %%
# %timeit print('hello world')
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# ...

# %%
# %%bash
# ls
# Out:
# dataset
# jupyter金融实践.ipynb
# picture
# reference
# saveplt.jpg
# 备份
# 实验.ipynb
# 第11章  产品销售额预测模型实例.ipynb
# 第12章 信用评分模型实例-七个变量-Copy1.ipynb
# 第12章 信用评分模型实例-七个变量.ipynb
# 第12章 信用评分模型实例-修订.ipynb
# 第13章 信用反欺诈模型实例.ipynb
# 第2章 Jupyter Notebook 界面.ipynb
# 第3章 Jupyter Notebook 基础操作.ipynb
# 第4章 Markdown语法介绍.ipynb
# 第5章 基本数据操作.ipynb
# 第6章 数据读取.ipynb
# 第7章 数据可视化.ipynb
# 第8章 机器学习.ipynb
# 第一部分-第一章.txt

# %%
# %%HTML
# Out:
# UsageError: %%HTML is a cell magic, but the cell body is empty.

# %% [markdown]
# # 一级标题
# ## 二级标题
# ### 三级标题
# #### 四级标题
# ##### 五级标题
# ###### 六级标题

# %%
# !ls

# %%
# %system ls

# %%
# %%bash ls

# %% [markdown]
# # print('hello ')

# %%
def hello():
    print('hello jupyter')

# hello()

# %%
print('hello world')
print('hello jupyter aaa')
